# %%
import csv
import pandas as pd

# %%
csv_path = ("Data/food_coded.csv")
food_df = pd.read_csv(csv_path)
food_df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
food_df = food_df.drop(["comfort_food", "comfort_food_reasons", "diet_current", "eating_changes", "father_profession", "fav_cuisine", "food_childhood", "healthy_meal", "ideal_diet", "meals_dinner_friend", "mother_profession", "type_sports"], axis=1)
food_df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
food_df["GPA"] = food_df["GPA"].replace(["Personal", "3.79 bitch", "Unknown"], ["3.6", "3.79", "3.7"])

# %%
food_df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
food_df["weight"] = food_df["weight"].replace(["I'm not answering this.", "Not sure, 240", "144 lbs"], ["160", "240", "144"])

# %%
food_df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
food_df.bfill(axis=0)
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 3           3.2       1          1               430           3.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# ...

# %%
food_df.count()
# Out:
# GPA                             123
# Gender                          125
# breakfast                       125
# calories_chicken                125
# calories_day                    106
# calories_scone                  124
# coffee                          125
# comfort_food_reasons_coded      106
# cook                            122
# comfort_food_reasons_coded.1    125
# cuisine                         108
# diet_current_coded              125
# drink                           123
# eating_changes_coded            125
# eating_changes_coded1           125
# eating_out                      125
# employment                      116
# ethnic_food                     125
# exercise                        112
# father_education                124
# fav_cuisine_coded               125
# fav_food                        123
# fries                           125
# fruit_day                       125
# grade_level                     125
# greek_food                      125
# ...

# %%
food_df = food_df.dropna()
food_df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 6    3.8       2          1               610           3.0           420.0
#
#    coffee  comfort_food_reasons_coded  cook  comfort_food_reasons_coded.1  \
# 1       2                         1.0   3.0                             1
# 2       2                         1.0   1.0                             1
# 3       2                         2.0   2.0                             2
# 4       2                         1.0   1.0                             1
# 6       2                         1.0   2.0                             1
#
# ...

# %%
food_df.count()
# Out:
# GPA                             59
# Gender                          59
# breakfast                       59
# calories_chicken                59
# calories_day                    59
# calories_scone                  59
# coffee                          59
# comfort_food_reasons_coded      59
# cook                            59
# comfort_food_reasons_coded.1    59
# cuisine                         59
# diet_current_coded              59
# drink                           59
# eating_changes_coded            59
# eating_changes_coded1           59
# eating_out                      59
# employment                      59
# ethnic_food                     59
# exercise                        59
# father_education                59
# fav_cuisine_coded               59
# fav_food                        59
# fries                           59
# fruit_day                       59
# grade_level                     59
# greek_food                      59
# healthy_feeling                 59
# ...

# %%
food_df.interpolate(method='pad', axis=0, limit_direction='forward'
