# %%
# Dependencies and Setup
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# Pathing for clean data
clean_data = "clean_data/clean_food_data.csv"
# Read the cleaned data
cleaned_data_df = pd.read_csv(clean_data)
cleaned_data_df
# Out:
#      Unnamed: 0    GPA  Gender  breakfast  calories_chicken  calories_day  \
# 0             0    2.4       2          1               430           3.0
# 1             1  3.654       1          1               610           3.0
# 2             2    3.2       1          1               430           3.0
# 3             3    3.5       1          1               720           2.0
# 4             4   2.25       1          1               610           3.0
# ..          ...    ...     ...        ...               ...           ...
# 119         119    3.5       1          1               610           4.0
# 120         120      3       1          1               265           2.0
# 121         121  3.882       1          1               720           2.0
# 122         122      3       2          1               720           4.0
# 123         123    3.9       1          1               430           4.0
#
#      calories_scone  coffee  comfort_food_reasons_coded  cook  ...  \
# 0             315.0       1                         9.0   2.0  ...
# 1             420.0       2                         1.0   3.0  ...
# 2             420.0       2                         2.0   2.0  ...
# 3             420.0       2                         1.0   1.0  ...
# 4             980.0       2                         4.0   3.0  ...
# ..              ...     ...                         ...   ...  ...
# 119           420.0       2                         2.0   3.0  ...
# 120           315.0       2                         2.0   3.0  ...
# 121           420.0       1                         2.0   3.0  ...
# 122           420.0       1                         2.0   3.0  ...
# 123           315.0       2                         2.0   3.0  ...
#
#      self_perception_weight  soup  sports  thai_food  tortilla_calories  \
# 0                       3.0   1.0     1.0          1             1165.0
# 1                       3.0   1.0     1.0          2              725.0
# 2                       5.0   1.0     2.0          5              725.0
# 3                       4.0   1.0     1.0          4              940.0
# 4                       5.0   1.0     2.0          4              940.0
# ..                      ...   ...     ...        ...                ...
# 119                     4.0   1.0     1.0          5              940.0
# 120                     4.0   1.0     1.0          4              940.0
# 121                     4.0   1.0     2.0          5              580.0
# 122                     2.0   2.0     2.0          1              940.0
# 123                     3.0   1.0     2.0          2              725.0
#
#      turkey_calories  veggies_day  vitamins  waffle_calories  weight
# 0                345            5         1             1315     187
# 1                690            4         2              900     155
# 2                690            3         1             1315     240
# 3                500            4         2              760     190
# 4                345            1         2             1315     190
# ..               ...          ...       ...              ...     ...
# 119              500            5         1             1315     156
# 120              500            5         2             1315     180
# 121              690            4         2             1315     120
# 122              500            3         1             1315     135
# 123              345            4         2              575     135
#
# [124 rows x 50 columns]

# %%
food_data_df = cleaned_data_df[["Gender","on_off_campus", "sports", "exercise", "cook"]]
food_data_df
# Out:
#      Gender  on_off_campus  sports  exercise  cook
# 0         2            1.0     1.0       1.0   2.0
# 1         1            1.0     1.0       1.0   3.0
# 2         1            1.0     2.0       3.0   2.0
# 3         1            1.0     1.0       1.0   1.0
# 4         1            1.0     2.0       2.0   3.0
# ..      ...            ...     ...       ...   ...
# 119       1            3.0     1.0       2.0   3.0
# 120       1            1.0     1.0       2.0   3.0
# 121       1            1.0     2.0       2.0   3.0
# 122       2            1.0     2.0       1.0   3.0
# 123       1            1.0     2.0       2.0   3.0
#
# [124 rows x 5 columns]

# %%
food_data_cooking_df = cleaned_data_df[["father_education", "mother_education", "parents_cook", "eating_out", "cook", "weight"]]
food_data_cooking_df
# Out:
#      father_education  mother_education  parents_cook  eating_out  cook  \
# 0                 5.0               1.0             1           3   2.0
# 1                 2.0               4.0             1           2   3.0
# 2                 2.0               4.0             1           2   2.0
# 3                 4.0               5.0             1           2   1.0
# 4                 1.0               1.0             2           1   3.0
# ..                ...               ...           ...         ...   ...
# 119               4.0               3.0             1           2   3.0
# 120               5.0               2.0             3           4   3.0
# 121               5.0               1.0             2           3   3.0
# 122               3.0               2.0             2           5   3.0
# 123               4.0               3.0             3           1   3.0
#
#      weight
# 0       187
# 1       155
# 2       240
# 3       190
# 4       190
# ..      ...
# 119     156
# 120     180
# 121     120
# 122     135
# 123     135
#
# [124 rows x 6 columns]

# %%
male_df = food_data_df[food_data_df["Gender"] == 1]["exercise"].value_counts()
male_group = male_df.tolist()
female_df = food_data_df[food_data_df["Gender"] == 2]["exercise"].value_counts()
female_group = female_df.tolist()

# %%
# Males 123 [34, 33, 8] no 45
# Females 123 [29, 16, 4] no 45

# %%
X = np.arange(3)
plt.figure(figsize=(12,8))
plt.bar(X - .2, male_group, color = 'lightblue', edgecolor='black', width =.4)
plt.bar(X + .2, female_group, color = 'pink',edgecolor='black', width =.4)
plt.locator_params(axis='x', nbins=4)
plt.xlim(-.5,2.5)
plt.xticks(range(0,len(male_df.index)),["Everyday","Twice or Three Times per Week","Once a Week"])
plt.title("Gender Breakdown of Exercise Responses")
plt.xlabel("Response Type")
plt.ylabel("Number of Participants")
plt.legend(["Males", "Females"], loc="best", prop={'size': 15})
plt.savefig('Images/Gender_Breakdown_of_Exercise_Responses.png')
plt.show()

# %% [markdown]
# Based on the responses of the sample population, there is no correlation to gender and the frequency in which the participants exercise. Though it is important to note that more males than females provided an answer to this question in the survey.

# %%
response_one = food_data_df[food_data_df["exercise"] == 1]
response_two = food_data_df[food_data_df["exercise"] == 2]
response_three = food_data_df[food_data_df["exercise"] == 3]

# %%
pies = ["Yes","No"]
colors = ["Lightblue", "pink"]
exercise_no_filter = food_data_df["sports"].value_counts()
response_1 = response_one["sports"].value_counts()
response_2 = response_two["sports"].value_counts()
response_3 = response_three["sports"].value_counts()
fig, axs = plt.subplots(2,3,figsize=(15,15))
axs[0,0].axis('off')
axs[0,2].axis('off')
axs[0,1].pie(exercise_no_filter, labels=pies, colors=colors,
    autopct="%1.1f%%", shadow=True, startangle=90, radius=2)
axs[0,1].set_title("Do you play sports?")
axs[1,0].pie(response_1, labels=pies, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
axs[1,0].set_title("Exercise Everday")
axs[1,1].pie(response_2, labels=pies, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
axs[1,1].set_title("Exercise Twice or Three Times per Week")
axs[1,2].pie(response_3, labels=pies, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
axs[1,2].set_title("Exercise Once a Week")
plt.axis("equal")
plt.savefig('Images/Sports_And_Excercise.png')
plt.show()

# %% [markdown]
# We can see that most student participants partake in sports and that playing sports does have an effect on the amount of times they exercise

# %%
food_data_df['on_off_campus'] = food_data_df['on_off_campus'].map({1:1, 2:2, 3:2, 4:2,})
plt.scatter(food_data_df["on_off_campus"], food_data_df["cook"], marker = "o",
            facecolors="pink", edgecolors="black", alpha=.75)
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(food_data_df["on_off_campus"], food_data_df["cook"])
regress_values = food_data_df["on_off_campus"] * slope + intercept
plt.locator_params(axis='x', nbins=2)
plt.xlim(0.5,2.5)
plt.xticks(range(1,3),["On Campus","Off Campus"])
plt.yticks(range(1,6),["Everyday","Few Times a Week","Sometimes","Only During Holidays","Never"])
line_eq = f'y= {str(round(slope,2))}x + {str(round(intercept,2))}'
plt.plot(food_data_df["on_off_campus"], regress_values, "r-")
plt.title("Living On/Off Campus & Cooking")
plt.xlabel("Living Situation")
plt.ylabel("Cooking")
print(f"The r-squared is: {rvalue}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig('Images/Living_Situation_Cooking.png')
plt.show()
# Out:
# <ipython-input-10-b8882d438ad6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_data_df['on_off_campus'] = food_data_df['on_off_campus'].map({1:1, 2:2, 3:2, 4:2,})
# The r-squared is: -0.1784371563011233
# The equation of the regression line is: y= -0.45x + 3.35

# %% [markdown]
# Using the found r-value of -0.17843, our r-squared correlation coefficient would be -0.03184. This would suggested there is no correlation between the frequency of cooking and living off campus compared to on campus.

# %%
col = food_data_cooking_df.loc[: , "father_education":"mother_education"]
food_data_cooking_df['average education of parents'] = col.mean(axis=1)
food_data_cooking_df
# Out:
# <ipython-input-11-0da5aa792fd0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_data_cooking_df['average education of parents'] = col.mean(axis=1)
#      father_education  mother_education  parents_cook  eating_out  cook  \
# 0                 5.0               1.0             1           3   2.0
# 1                 2.0               4.0             1           2   3.0
# 2                 2.0               4.0             1           2   2.0
# 3                 4.0               5.0             1           2   1.0
# 4                 1.0               1.0             2           1   3.0
# ..                ...               ...           ...         ...   ...
# 119               4.0               3.0             1           2   3.0
# 120               5.0               2.0             3           4   3.0
# 121               5.0               1.0             2           3   3.0
# 122               3.0               2.0             2           5   3.0
# 123               4.0               3.0             3           1   3.0
#
#      weight  average education of parents
# 0       187                           3.0
# 1       155                           3.0
# 2       240                           3.0
# 3       190                           4.5
# 4       190                           1.0
# ..      ...                           ...
# 119     156                           3.5
# 120     180                           3.5
# 121     120                           3.0
# 122     135                           2.5
# 123     135                           3.5
#
# [124 rows x 7 columns]

# %%
plt.scatter(food_data_cooking_df['average education of parents'], food_data_cooking_df["eating_out"], marker = "o", facecolors="pink", edgecolors="black", s=food_data_cooking_df["eating_out"], alpha=.75)

(slope, intercept, rvalue, pvalue, stderr) = linregress(food_data_cooking_df['average education of parents'], food_data_cooking_df["eating_out"])

regress_values = food_data_cooking_df['average education of parents'] * slope + intercept
plt.xticks(range(1,6),["< high school","high school", "some college", "< college", "graduate degree"])
plt.yticks(range(1,6),["Never","1-2 times","2-3 times","3-5 times","everyday"])

line_eq = f'y= {str(round(slope,2))}x + {str(round(intercept,2))}'

plt.plot(food_data_cooking_df['average education of parents'], regress_values, "r-")
plt.title("Impact of parents' education on people's eating habit")
plt.xlabel("Parents' education")
plt.ylabel("Eating Out Frequency")

print(f"The r-squared is: {rvalue}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig('Images/Parents_education_on_peoples_eating_habits.png')
plt.show()

#There is minimum relevance between a person's eating out habit and parents' education level. However, we can see that the higher level the parents' education is, the more often will people eat out
# Out:
# The r-squared is: 0.12938009729910624
# The equation of the regression line is: y= 0.16x + 2.02

# %% [markdown]
# Using an r value of 0.0129380, our r-squared correlation coefficient would be 0.01674, meaning that there is no correlation between the parents' education level and the effect on eating out.

# %%
plt.scatter(food_data_cooking_df['average education of parents'], food_data_cooking_df["parents_cook"], marker = "o", facecolors="red", edgecolors="black", s=food_data_cooking_df["eating_out"], alpha=.75)

(slope, intercept, rvalue, pvalue, stderr) = linregress(food_data_cooking_df['average education of parents'], food_data_cooking_df["parents_cook"])

regress_values = food_data_cooking_df['average education of parents'] * slope + intercept

plt.xticks(range(1,6),["< high school","high school", "some college", "< college", "graduate degree"])
plt.yticks(range(1,6),["Everyday","2-3 times/week","1-2 times/week","Only during holidays","never"])


line_eq = f'y= {str(round(slope,2))}x + {str(round(intercept,2))}'

plt.plot(food_data_cooking_df['average education of parents'], regress_values, "r-")
plt.title("Impact of parents' education on people's eating habit")
plt.xlabel("Parents' education")
plt.ylabel("Frequency of parents cooking at home")

print(f"The r-squared is: {rvalue}")
print(f"The equation of the regression line is: {line_eq}")
plt.savefig('Images/parents_cooking.png')
plt.show()

#Most parents cook at home almost everyday or at least 2-3 times a week regardless of the education level
# Out:
# The r-squared is: 0.03580824435819679
# The equation of the regression line is: y= 0.03x + 1.43

# %% [markdown]
# Taking the r-value of 0.03580, our r-squared correlation coefficient would be 0.0013, meaning that there is no correlation between the frequency of which parents cooked at home and their level of education.

# %%
# data to plot
avg_parents_cook = food_data_cooking_df["parents_cook"].mean()
avg_eating_out = food_data_cooking_df["eating_out"].mean()
avg_self_cook = food_data_cooking_df["cook"].mean()

# create plot
fig, ax = plt.subplots()
bar_width = 0.2
X = np.arange(1)
plt.xticks(range(1,4),["parents cook","eating out","self cook"])
p1 = plt.bar(X, avg_parents_cook, bar_width, color='lightblue', label='parents cook')
p2 = plt.bar(X + bar_width, avg_eating_out, bar_width, color='pink', label='eating out')
p3 = plt.bar(X + bar_width * 2, avg_eating_out, bar_width, color='wheat', label='self cook')

plt.yticks(range(1,4),["Everyday","couple times/week","Not often"])

plt.xlabel('Eating habit')
plt.ylabel('Frequency')
plt.title('Eating habit frequency')

plt.legend()

plt.savefig('Images/eating_habit_frequency.png')
plt.show()

# %% [markdown]
# It appears that there it is more frequent that students will eat out and cook for themselves several times a week and only eat what their parents cook a few days a week

# %%
eating_out_xa = food_data_cooking_df["eating_out"]
weight_ya = food_data_cooking_df["weight"]
plt.xticks(range(1,6),["Never","1-2 times","2-3 times","3-5 times","everyday"])

plt.plot(eating_out_xa, weight_ya)
plt.title("Correlation between frequency of eating out and a person's weight")
plt.xlabel("eating out frequency")
plt.ylabel("weight")
plt.savefig('Images/weight_and_eating_out.png')
plt.show()

# %% [markdown]
# There appears to be no correlation between a student's weight and the frequency in which they eat out

# %% [markdown]
# Ultimately, our analysis seems to suggest that there is no correlation between any of the relationships that we were examining. Any correlation that we calculated was only slightly above or slightly below 0, meaning while there is the slightest bit of a correlation, it is essential 0.
#
# How often do they cook/exercise?
# 1.	Any correlation between gender and exercise regimen?
# a.	There does not appear to be a correlation between gender and exercise. The results appear to be even between the two genders. It appears that it a majority of the participants in the survey from the sample population regularly exercise.
# 2.	Does playing sports affect how often you exercise?
# a.	There does not seem to be a significant impact between playing sports and exercising with 61.3% of the participants responding that they play sports
# 3.	Does living situation affect how often someone cooks?
# a.	Based on the data collected and the calculation of the correlation coefficient, there is a slightly negative correlation between the frequency of cooking and the students living situation. However, the correlation is so small (-0.03184) that it is insignificant
# How do parents’ education influence their eating habits?
# 1.	Any correlations between parents’ education and students’ eating habits?
# a.	Based on the data collected, our r-squared value is 0.01674, meaning that the correlation is not significant enough to determine if the parents’ education level affects how often they eat out, meaning we have no correlation between the two.
# 2.	Any correlations between patents’ education and cooking at home?
# a.	Our correlation coefficient for this data was 0.0013 meaning there is essentially no correlation between the parents’ education and how frequently they cook at home.
# 3.	Compare student cooking, parent cooking, or students eating out.
# a.	It appears that many of the students who participated frequently either eat out or cook for themselves with few saying that occasionally they eat what their parents cook for them.
# 4.	Is there a correlation between student’s weight compared to eating out?
# a.	There does not appear to be any kind of correlation between how frequently a student eats out and their weight.
